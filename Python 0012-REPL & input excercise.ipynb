# %% [markdown]
# # How to take multiple inputs in a single line: Python?

# %%
print(help(input))
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplentedError if active frontend doesn't support stdin.
#
# None

# %% [markdown]
#     variable = datatype(input(‘<statement>’))

# %%
s=input('Enter a character:')
n=int(input('Enter a number:'))
# Out:
# Enter a character:charan
# Enter a number:5

# %% [markdown]
# ## To take multiple inputs

# %%
a=input('Enter a character:')
b=input('Enter a character:')
print(a,b)
# Out:
# Enter a character:a
# Enter a character:b
# a b

# %% [markdown]
# ## Take multiple input with a single line in Python

# %%
a,b = input(),input()
print(a,b)
# Out:
# a
# b
# a b

# %% [markdown]
#      if we want to code in a single line and also want to give input in a single line then go for split() method

# %%
a,b=input('Enter two characters separated by space:').split()

print(a,b)
# Out:
# Enter two characters separated by space:A B
# A B

# %% [markdown]
# # Using split() method :
#
#     input().split(separator, maxsplit)

# %%
# Python program showing how to 
# multiple input using split 
  
# taking two inputs at a time 
x, y = input("Enter a two value: ").split() 
print("Number of boys: ", x) 
print("Number of girls: ", y) 
print() 
  
# taking three inputs at a time 
x, y, z = input("Enter a three value: ").split() 
print("Total number of students: ", x) 
print("Number of boys is : ", y) 
print("Number of girls is : ", z) 
print() 
  
# taking two inputs at a time 
a, b = input("Enter a two value: ").split() 
print("First number is {} and second number is {}".format(a, b)) 
print() 
  
# taking multiple inputs at a time  
# and type casting using list() function 
x = list(map(int, input("Enter a multiple value: ").split())) 
print("List of students: ", x)

# %% [markdown]
# # Using for Loop and append

# %%
Y = []
n = 5
print("\t")
for i in range(0,n):
    item = float(input())
    Y.append(item)
print(Y[:-1])
# Out:
#
# 1
# 2
# 3
# 4
# 5
# [1.0, 2.0, 3.0, 4.0]

# %%
Y = []
n = 5
print("\n")
for i in range(0,n):
    item = float(input())
    Y.append(item)
print(Y[:-1])
# Out:
# 1
# 2
# 3
# 4
# 5
# [1.0, 2.0, 3.0, 4.0]

# %%
floatNumbers = []
n = int(input("Enter the list size : "))

print("\n")
for i in range(0, n):
    print("Enter number at location", i, ":")
    item = float(input())
    floatNumbers.append(item)
    
print("User List is ", floatNumbers)
# Out:
# Enter the list size : 3
#
#
# Enter number at location 0 :
# 1
# Enter number at location 1 :
# 2
# Enter number at location 2 :
# 3
# User List is  [1.0, 2.0, 3.0]

# %%
# try block to handle the exception 
try: 
    my_list = [] 
      
    while True: 
        my_list.append(int(float(input())) )
          
# if the input is not-integer, just print the list 
except: 
    print(my_list)
# Out:
# 1
# 2
# 3
# 4
#
# [1, 2, 3, 4]

# %% [markdown]
# # Using List comprehension :

# %%
# Python program showing 
# how to take multiple input 
# using List comprehension 
  
# taking two input at a time 
x, y = [int(x) for x in input("Enter two value: ").split()] 
print("First Number is: ", x) 
print("Second Number is: ", y) 
print() 
  
# taking three input at a time 
x, y, z = [int(x) for x in input("Enter three value: ").split()] 
print("First Number is: ", x) 
print("Second Number is: ", y) 
print("Third Number is: ", z) 
print() 
  
# taking two inputs at a time 
x, y = [int(x) for x in input("Enter two value: ").split()] 
print("First number is {} and second number is {}".format(x, y)) 
print() 
  
# taking multiple inputs at a time  
x = [int(x) for x in input("Enter multiple value: ").split()] 
print("Number of list is: ", x)

# %% [markdown]
#     taking multiple inputs sepreated by ,

# %%
user_input = input("Enter Numbers\n").split(',')
#strip is used to remove the white space. Not mandatory
all_numbers = [int(x.strip()) for x in user_input]
for i in all_numbers:
    print(i)
# Out:
# Enter Numbers
# 1,2,3,4
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Using map() function
#     map() is another function that will help us take multiple inputs from the user. In general, the syntax for map function is map (fun, iter). Here fun is the function to which the map function passes each iterable.

# %%
variable 1, variable 2, variable 3 = map(int,input().split())

# %%
#multiple inputs in Python using map
x, y = map(int, input("Enter two values: ").split())
print("First Number is: ", x) 
print("Second Number is: ", y)

#multiple inputs in Python using map
x, y = map(str, input("Enter your first and last name ").split())
print("First Name is: ", x) 
print("Second Name is: ", y)
# Out:
# Enter two values: 2 3
# First Number is:  2
# Second Number is:  3
# Enter your first and last name charan kumar
# First Name is:  charan
# Second Name is:  kumar

# %% [markdown]
# ## Exampel Problem
#
# https://www.hackerrank.com/challenges/py-collections-namedtuple/problem

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     In short, we’re looking for 3 main inputs:
#
#     Input 1: The number of lines of data to be entered
#     Input 2: The column names for the data
#     Input 3: The data

# %%
from collections import namedtuple

# Assign our first 2 inputs to their variable names
(students, column_names) = (int(input("No. of students: ")), 
                                 input("Column Names:\n").split())
# Create the Grade named tuple
Grade = namedtuple('Grade', column_names)
# Create a list of MARKS collected from user input
marks = [int(Grade._make(input().split()).MARKS) for _ in range(students)]
# Calculate the average mark
print("\nAverage Grade = {}".format((sum(marks) / len(marks))))
# Out:
# No. of students: 2
# Column Names:
# ID         MARKS      NAME       CLASS
# 1         98         charan      first
# 2        45         kumar       second
#
# Average Grade = 71.5

# %% [markdown]
# https://www.inoutcode.com/python/input-output/python-input/
#
#
# https://stackoverflow.com/questions/7378091/taking-multiple-inputs-from-user-in-python
#
# https://tutorialspoint.dev/language/python/taking-multiple-inputs-from-user-in-python
